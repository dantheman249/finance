# %%
#import packages
import datetime as dt 
import lxml
from lxml import html, etree
import requests
import numpy as np
import pandas as pd
import pandas_datareader
from pandas_datareader import data as pdr
import time
from time import sleep
import string
import yfinance as yf
from bs4 import BeautifulSoup
import urllib
import io
import os
import pandasql
from pandasql import sqldf
import re
import gc
import zipfile
from zipfile import ZipFile
from io import StringIO
import sys

from os import listdir
from os.path import isfile, join
import psutil

from collections import Counter
import linecache
import tracemalloc

import reshape

# %%
df = pd.read_csv("total_finance_table.csv")

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# name           object
# sic           float64
# fye           float64
# form           object
# period        float64
# fy            float64
# fp             object
# filed           int64
# ticker         object
# cik             int64
# ddate           int64
# qtrs          float64
# uom            object
# value         float64
# adsh           object
# stmt           object
# tag            object
# version        object
# plabel         object
# dtype: object

# %%
# want to be able to get the plabels and tags and values of a company for a year where data is missing 

#ex1: stz, cik = 16918 has no shares outstanding data

_year = 2019.0
_ticker = 'aap' 
#_stmt = 'BS'


ex1 = df[(df['fy'] == _year)
        & (df['ticker'] == _ticker)
        ]

#print(ex1)
ex1.to_csv(_ticker + '_'+str(_year)+".csv")
# Out:
#          Unnamed: 0                    name     sic     fye  form      period  \
# 1562831       15398  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1562832       15399  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1562833       15400  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1562834       15401  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1562835       15402  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# ...             ...                     ...     ...     ...   ...         ...
# 1725588      182342  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1725589      182343  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1733767      191657  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1733768      191658  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
# 1733769      191659  ADVANCE AUTO PARTS INC  5531.0  1231.0  10-K  20191231.0
#
#              fy  fp     filed ticker      cik     ddate  qtrs  uom  \
# 1562831  2019.0  FY  20200218    aap  1158449  20191231   0.0  USD
# 1562832  2019.0  FY  20200218    aap  1158449  20181231   0.0  USD
# 1562833  2019.0  FY  20200218    aap  1158449  20191231   0.0  USD
# 1562834  2019.0  FY  20200218    aap  1158449  20181231   0.0  USD
# 1562835  2019.0  FY  20200218    aap  1158449  20181231   0.0  USD
# ...         ...  ..       ...    ...      ...       ...   ...  ...
# 1725588  2019.0  FY  20200218    aap  1158449  20171231   4.0  USD
# 1725589  2019.0  FY  20200218    aap  1158449  20191231   4.0  USD
# 1733767  2019.0  FY  20200218    aap  1158449  20191231   4.0  USD
# 1733768  2019.0  FY  20200218    aap  1158449  20181231   4.0  USD
# 1733769  2019.0  FY  20200218    aap  1158449  20171231   4.0  USD
#
#                 value                  adsh stmt  \
# 1562831  3.421987e+09  0001158449-20-000035   BS
# 1562832  3.172790e+09  0001158449-20-000035   BS
# 1562833  6.894690e+08  0001158449-20-000035   BS
# 1562834  6.249720e+08  0001158449-20-000035   BS
# 1562835 -4.419300e+07  0001158449-20-000035   BS
# ...               ...                   ...  ...
# 1725588  0.000000e+00  0001158449-20-000035   EQ
# 1725589  0.000000e+00  0001158449-20-000035   EQ
# 1733767  2.015190e+08  0001158449-20-000035   CF
# 1733768  0.000000e+00  0001158449-20-000035   CF
# 1733769  0.000000e+00  0001158449-20-000035   CF
#
#                                                        tag  \
# 1562831                             AccountsPayableCurrent
# 1562832                             AccountsPayableCurrent
# 1562833                       AccountsReceivableNetCurrent
# 1562834                       AccountsReceivableNetCurrent
# 1562835    AccumulatedOtherComprehensiveIncomeLossNetOfTax
# ...                                                    ...
# 1725588  StockIssuedDuringPeriodValueRestrictedStockAwa...
# 1725589  StockIssuedDuringPeriodValueRestrictedStockAwa...
# 1733767  Indefinitelivedintangibleassetpurchaseincludin...
# 1733768  Indefinitelivedintangibleassetpurchaseincludin...
# 1733769  Indefinitelivedintangibleassetpurchaseincludin...
#
#                       version  \
# 1562831          us-gaap/2019
# 1562832          us-gaap/2019
# 1562833          us-gaap/2019
# 1562834          us-gaap/2019
# 1562835          us-gaap/2019
# ...                       ...
# 1725588          us-gaap/2019
# 1725589          us-gaap/2019
# 1733767  0001158449-20-000035
# 1733768  0001158449-20-000035
# 1733769  0001158449-20-000035
#
#                                                     plabel
# 1562831                                   Accounts payable
# 1562832                                   Accounts payable
# 1562833                                   Receivables, net
# 1562834                                   Receivables, net
# 1562835               Accumulated other comprehensive loss
# ...                                                    ...
# 1725588  Restricted stock, restricted stock units and d...
# 1725589  Restricted stock, restricted stock units and d...
# 1733767   Purchase of an indefinite-lived intangible asset
# 1733768   Purchase of an indefinite-lived intangible asset
# 1733769   Purchase of an indefinite-lived intangible asset
#
# [352 rows x 20 columns]

# %%
# Out:
#          Unnamed: 0          name     sic     fye  form      period      fy  \
# 1565222       17842  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1565223       17843  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1565224       17844  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1565225       17845  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1565226       17846  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# ...             ...           ...     ...     ...   ...         ...     ...
# 1737166      195374  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1737167      195375  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1737168      195376  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1737169      195377  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
# 1737170      195378  COCA COLA CO  2080.0  1231.0  10-K  20191231.0  2019.0
#
#          fp     filed ticker    cik     ddate  qtrs  uom         value  \
# 1565222  FY  20200224     ko  21344  20191231   0.0  USD  1.131200e+10
# 1565223  FY  20200224     ko  21344  20181231   0.0  USD  9.533000e+09
# 1565224  FY  20200224     ko  21344  20191231   0.0  USD  3.971000e+09
# 1565225  FY  20200224     ko  21344  20181231   0.0  USD  3.685000e+09
# 1565226  FY  20200224     ko  21344  20191231   0.0  USD  4.140000e+08
# ...      ..       ...    ...    ...       ...   ...  ...           ...
# 1737166  FY  20200224     ko  21344  20171231   4.0  USD  3.821000e+09
# 1737167  FY  20200224     ko  21344  20181231   4.0  USD  1.362000e+09
# 1737168  FY  20200224     ko  21344  20191231   0.0  USD  2.570000e+08
# 1737169  FY  20200224     ko  21344  20181231   0.0  USD  2.410000e+08
# 1737170  FY  20200224     ko  21344  20171231   0.0  USD  2.710000e+08
#
#                          adsh stmt  \
# 1565222  0000021344-20-000006   BS
# 1565223  0000021344-20-000006   BS
# 1565224  0000021344-20-000006   BS
# 1565225  0000021344-20-000006   BS
# 1565226  0000021344-20-000006   BS
# ...                       ...  ...
# 1737166  0000021344-20-000006   CF
# 1737167  0000021344-20-000006   CF
# 1737168  0000021344-20-000006   CF
# 1737169  0000021344-20-000006   CF
# 1737170  0000021344-20-000006   CF
#
#                                                        tag  \
# 1565222        AccountsPayableAndAccruedLiabilitiesCurrent
# 1565223        AccountsPayableAndAccruedLiabilitiesCurrent
# 1565224                       AccountsReceivableNetCurrent
# 1565225                       AccountsReceivableNetCurrent
# 1565226                          AccruedIncomeTaxesCurrent
# ...                                                    ...
# 1737166  ProceedsfromDisposalsofbusinessesequitymethodi...
# 1737167  ProceedsfromDisposalsofbusinessesequitymethodi...
# 1737168  RestrictedCashandRestrictedCashEquivalentsnoti...
# 1737169  RestrictedCashandRestrictedCashEquivalentsnoti...
# 1737170  RestrictedCashandRestrictedCashEquivalentsnoti...
#
#                       version  \
# 1565222          us-gaap/2019
# 1565223          us-gaap/2019
# 1565224          us-gaap/2019
# 1565225          us-gaap/2019
# 1565226          us-gaap/2019
# ...                       ...
# 1737166  0000021344-20-000006
# 1737167  0000021344-20-000006
# 1737168  0000021344-20-000006
# 1737169  0000021344-20-000006
# 1737170  0000021344-20-000006
#
#                                                     plabel
# 1565222              Accounts payable and accrued expenses
# 1565223              Accounts payable and accrued expenses
# 1565224  Trade accounts receivable, less allowances of ...
# 1565225  Trade accounts receivable, less allowances of ...
# 1565226                               Accrued income taxes
# ...                                                    ...
# 1737166  Proceeds from disposals of businesses, equity ...
# 1737167  Proceeds from disposals of businesses, equity ...
# 1737168  Restricted Cash and Restricted Cash Equivalent...
# 1737169  Restricted Cash and Restricted Cash Equivalent...
# 1737170  Restricted Cash and Restricted Cash Equivalent...
#
# [290 rows x 20 columns]

# %%
#debug df
label_counts = df.groupby(['plabel', 
'tag', 
'stmt', 
'qtrs']).size().reset_index(name="frequency")

ordered_label = sqldf("""
SELECT 
* 
FROM 
label_counts 
WHERE frequency >= 10
ORDER BY 
stmt, 
frequency DESC
""")

ordered_label.to_csv("label_counts.csv")
print(ordered_label)
